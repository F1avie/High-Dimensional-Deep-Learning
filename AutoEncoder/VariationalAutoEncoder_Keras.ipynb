# %% [markdown]
# <a href="https://colab.research.google.com/github/wikistat/High-Dimensional-Deep-Learning/blob/master/AutoEncoder/VariationalAutoEncoder_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <a href="http://www.insa-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo-insa.jpg" style="float:left; max-width: 120px; display: inline" alt="INSA"/></a>
# <a href="http://wikistat.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/wikistat.jpg" style="max-width: 150px; display: inline"  alt="Wikistat"/></a>
# <a href="http://www.math.univ-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo_imt.jpg" width=400,  style="float:right;  display: inline" alt="IMT"/> </a>
#
# </center>

# %% [markdown]
# # Files & Data (Google Colab)
#
# If you're running this notebook on Google colab, you do not have access to the `solutions` folder you get by cloning the repository locally.
#
# The following lines will allow you to build the folders and the files you need for this TP.
#
# **WARNING 1** Do not run this line localy.
# **WARNING 2** The magic command `%load` does not work work on google colab, you will have to copy-paste the solution on the notebook.

# %%
! mkdir image
! wget . https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/vae_mlp_decoder.png
! wget . https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/vae_mlp_vae.png
! wget image https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/image/vae_2.svg
! wget image https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/image/vae_3.svg
! mkdir solutions
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/compare_sparsity_decoded_imgs.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/compare_sparsity_encoded_imgs.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/convolutional_autoencoder.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/decoded_images_both_method.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/decoder_vae.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/generate_single_sample.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/simple_autoencoder.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/vae.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/train_outlier_vae.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/error_distribution.py
# Out:
# mkdir: impossible de créer le répertoire «image»: Le fichier existe
# --2022-10-19 11:09:33--  http://./
# Résolution de . (.)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « . »
# --2022-10-19 11:09:33--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/vae_mlp_decoder.png
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/vae_mlp_decoder.png [suivant]
# --2022-10-19 11:09:34--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/vae_mlp_decoder.png
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 22573 (22K) [image/png]
# Sauvegarde en : « vae_mlp_decoder.png.12 »
#
# vae_mlp_decoder.png 100%[===================>]  22,04K  --.-KB/s    ds 0,002s
#
# 2022-10-19 11:09:34 (13,7 MB/s) — « vae_mlp_decoder.png.12 » sauvegardé [22573/22573]
#
# Terminé — 2022-10-19 11:09:34 —
# Temps total effectif : 0,6s
# Téléchargés : 1 fichiers, 22K en 0,002s (13,7 MB/s)
# --2022-10-19 11:09:34--  http://./
# Résolution de . (.)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « . »
# --2022-10-19 11:09:34--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/vae_mlp_vae.png
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/vae_mlp_vae.png [suivant]
# --2022-10-19 11:09:34--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/vae_mlp_vae.png
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 21694 (21K) [image/png]
# Sauvegarde en : « vae_mlp_vae.png.12 »
#
# vae_mlp_vae.png.12  100%[===================>]  21,19K  --.-KB/s    ds 0,001s
#
# 2022-10-19 11:09:34 (13,9 MB/s) — « vae_mlp_vae.png.12 » sauvegardé [21694/21694]
#
# Terminé — 2022-10-19 11:09:34 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 21K en 0,001s (13,9 MB/s)
# --2022-10-19 11:09:35--  http://image/
# Résolution de image (image)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « image »
# --2022-10-19 11:09:35--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/image/vae_2.svg
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/image/vae_2.svg [suivant]
# --2022-10-19 11:09:35--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/image/vae_2.svg
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 206667 (202K) [image/svg+xml]
# Sauvegarde en : « vae_2.svg.11 »
#
# vae_2.svg.11        100%[===================>] 201,82K  --.-KB/s    ds 0,04s
#
# 2022-10-19 11:09:35 (4,77 MB/s) — « vae_2.svg.11 » sauvegardé [206667/206667]
#
# Terminé — 2022-10-19 11:09:35 —
# Temps total effectif : 0,6s
# Téléchargés : 1 fichiers, 202K en 0,04s (4,77 MB/s)
# --2022-10-19 11:09:35--  http://image/
# Résolution de image (image)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « image »
# --2022-10-19 11:09:35--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/image/vae_3.svg
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/image/vae_3.svg [suivant]
# --2022-10-19 11:09:36--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/image/vae_3.svg
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 452473 (442K) [image/svg+xml]
# Sauvegarde en : « vae_3.svg.11 »
#
# vae_3.svg.11        100%[===================>] 441,87K  --.-KB/s    ds 0,06s
#
# 2022-10-19 11:09:36 (7,36 MB/s) — « vae_3.svg.11 » sauvegardé [452473/452473]
#
# Terminé — 2022-10-19 11:09:36 —
# Temps total effectif : 0,7s
# Téléchargés : 1 fichiers, 442K en 0,06s (7,36 MB/s)
# mkdir: impossible de créer le répertoire «solutions»: Le fichier existe
# --2022-10-19 11:09:36--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:36--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/compare_sparsity_decoded_imgs.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/compare_sparsity_decoded_imgs.py [suivant]
# --2022-10-19 11:09:36--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/compare_sparsity_decoded_imgs.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 799 [text/plain]
# Sauvegarde en : « compare_sparsity_decoded_imgs.py.11 »
#
# compare_sparsity_de 100%[===================>]     799  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:37 (19,0 MB/s) — « compare_sparsity_decoded_imgs.py.11 » sauvegardé [799/799]
#
# Terminé — 2022-10-19 11:09:37 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 799 en 0s (19,0 MB/s)
# --2022-10-19 11:09:37--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:37--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/compare_sparsity_encoded_imgs.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/compare_sparsity_encoded_imgs.py [suivant]
# --2022-10-19 11:09:37--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/compare_sparsity_encoded_imgs.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 455 [text/plain]
# Sauvegarde en : « compare_sparsity_encoded_imgs.py.11 »
#
# compare_sparsity_en 100%[===================>]     455  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:37 (11,6 MB/s) — « compare_sparsity_encoded_imgs.py.11 » sauvegardé [455/455]
#
# Terminé — 2022-10-19 11:09:37 —
# Temps total effectif : 0,6s
# Téléchargés : 1 fichiers, 455 en 0s (11,6 MB/s)
# --2022-10-19 11:09:38--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:38--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/convolutional_autoencoder.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/convolutional_autoencoder.py [suivant]
# --2022-10-19 11:09:38--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/convolutional_autoencoder.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1063 (1,0K) [text/plain]
# Sauvegarde en : « convolutional_autoencoder.py.11 »
#
# convolutional_autoe 100%[===================>]   1,04K  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:38 (29,6 MB/s) — « convolutional_autoencoder.py.11 » sauvegardé [1063/1063]
#
# Terminé — 2022-10-19 11:09:38 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 1,0K en 0s (29,6 MB/s)
# --2022-10-19 11:09:38--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:38--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/decoded_images_both_method.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/decoded_images_both_method.py [suivant]
# --2022-10-19 11:09:38--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/decoded_images_both_method.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1129 (1,1K) [text/plain]
# Sauvegarde en : « decoded_images_both_method.py.11 »
#
# decoded_images_both 100%[===================>]   1,10K  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:39 (28,4 MB/s) — « decoded_images_both_method.py.11 » sauvegardé [1129/1129]
#
# Terminé — 2022-10-19 11:09:39 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 1,1K en 0s (28,4 MB/s)
# --2022-10-19 11:09:39--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:39--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/decoder_vae.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/decoder_vae.py [suivant]
# --2022-10-19 11:09:39--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/decoder_vae.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 292 [text/plain]
# Sauvegarde en : « decoder_vae.py.11 »
#
# decoder_vae.py.11   100%[===================>]     292  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:39 (7,67 MB/s) — « decoder_vae.py.11 » sauvegardé [292/292]
#
# Terminé — 2022-10-19 11:09:39 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 292 en 0s (7,67 MB/s)
# --2022-10-19 11:09:39--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:39--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/generate_single_sample.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/generate_single_sample.py [suivant]
# --2022-10-19 11:09:40--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/generate_single_sample.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 141 [text/plain]
# Sauvegarde en : « generate_single_sample.py.11 »
#
# generate_single_sam 100%[===================>]     141  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:40 (4,22 MB/s) — « generate_single_sample.py.11 » sauvegardé [141/141]
#
# Terminé — 2022-10-19 11:09:40 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 141 en 0s (4,22 MB/s)
# --2022-10-19 11:09:40--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:40--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/simple_autoencoder.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/simple_autoencoder.py [suivant]
# --2022-10-19 11:09:40--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/simple_autoencoder.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 260 [text/plain]
# Sauvegarde en : « simple_autoencoder.py.11 »
#
# simple_autoencoder. 100%[===================>]     260  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:41 (5,65 MB/s) — « simple_autoencoder.py.11 » sauvegardé [260/260]
#
# Terminé — 2022-10-19 11:09:41 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 260 en 0s (5,65 MB/s)
# --2022-10-19 11:09:41--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:41--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/vae.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/vae.py [suivant]
# --2022-10-19 11:09:41--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/vae.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 120 [text/plain]
# Sauvegarde en : « vae.py.8 »
#
# vae.py.8            100%[===================>]     120  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:41 (2,76 MB/s) — « vae.py.8 » sauvegardé [120/120]
#
# Terminé — 2022-10-19 11:09:41 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 120 en 0s (2,76 MB/s)
# --2022-10-19 11:09:41--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:41--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/train_outlier_vae.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/train_outlier_vae.py [suivant]
# --2022-10-19 11:09:42--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/train_outlier_vae.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1122 (1,1K) [text/plain]
# Sauvegarde en : « train_outlier_vae.py.8 »
#
# train_outlier_vae.p 100%[===================>]   1,10K  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:42 (32,8 MB/s) — « train_outlier_vae.py.8 » sauvegardé [1122/1122]
#
# Terminé — 2022-10-19 11:09:42 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 1,1K en 0s (32,8 MB/s)
# --2022-10-19 11:09:42--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:09:42--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/error_distribution.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/error_distribution.py [suivant]
# --2022-10-19 11:09:42--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/error_distribution.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 515 [text/plain]
# Sauvegarde en : « error_distribution.py.8 »
#
# error_distribution. 100%[===================>]     515  --.-KB/s    ds 0s
#
# 2022-10-19 11:09:43 (12,1 MB/s) — « error_distribution.py.8 » sauvegardé [515/515]
#
# Terminé — 2022-10-19 11:09:43 —
# Temps total effectif : 0,5s
# Téléchargés : 1 fichiers, 515 en 0s (12,1 MB/s)

# %% [markdown]
# # High Dimensional & Deep Learning : Variational Autoencoders

# %% [markdown]
# ## What is a Variational Autoencoder

# %% [markdown]
# A variational autoencoder is an autoencoder that learns a latent variable model for its input data.

# %% [markdown]
# ## Objective

# %% [markdown]
# * Build a simple Variational Auto Encoder
# * Use Variational Auto Encoder for Number Generation
# * Use Variational Auto Encoder To anomaly detection
# * Write a Convolutional Variational Auto Encoder
# * Use the Keras Model APi

# %% [markdown]
# ## Library

# %%
from tensorflow.keras.datasets import mnist
import tensorflow.keras.preprocessing.image as kpi
import tensorflow.keras.models as km
import tensorflow.keras.layers as kl
import tensorflow.keras.losses as kloss
import tensorflow.keras.regularizers as kr
import tensorflow.keras.backend as K
import tensorflow.keras.utils as ku

import numpy as np
import scipy as sc

import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style("whitegrid")

import tensorflow as tf
print(tf.test.is_gpu_available())
# Out:
# 2022-10-19 11:09:43.626248: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /tmp/ipykernel_21912/3792752704.py:18: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# 2022-10-19 11:09:50.712826: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-19 11:09:50.713299: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-19 11:09:50.714533: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-10-19 11:09:50.787386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-10-19 11:09:50.787446: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-19 11:09:50.795144: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-19 11:09:50.795298: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-10-19 11:09:50.797561: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:09:50.798246: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:09:50.802430: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:09:50.803780: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-19 11:09:50.804083: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-19 11:09:50.806026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-19 11:09:50.806079: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-19 11:09:51.385069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-19 11:09:51.385100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-10-19 11:09:51.385108: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-10-19 11:09:51.386608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/device:GPU:0 with 9987 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:65:00.0, compute capability: 6.1)

# %%
configuration = tf.compat.v1.ConfigProto()
configuration.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=configuration)
# Out:
# 2022-10-19 11:09:51.400249: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-19 11:09:51.401136: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-10-19 11:09:51.401215: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-19 11:09:51.401296: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-19 11:09:51.401312: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-10-19 11:09:51.401325: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:09:51.401338: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:09:51.401351: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:09:51.401365: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-19 11:09:51.401378: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-19 11:09:51.402527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-19 11:09:51.402604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-19 11:09:51.402629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-10-19 11:09:51.402650: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-10-19 11:09:51.403746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9987 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:65:00.0, compute capability: 6.1)

# %% [markdown]
# ## Data

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
input_dim = np.prod(x_train.shape[1:])
n_train = x_train.shape[0]
n_test = x_test.shape[0]
x_train = x_train.reshape((n_train, input_dim))
x_test = x_test.reshape((n_test, input_dim))

# %% [markdown]
# ## Keras Model API

# %% [markdown]
# In the previous TP on image classification of the autoencoder notebook we have used the `Sequential` method to build model.
#
# Sequential Method have limits when the architecture we want is not *linear* or when we want to build a layer on top on two different entries.
#
# The `Model` API can sometimes be less intuitive but is much more flexible than the `Sequential` method. We will use it all along this TP.

# %% [markdown]
# ## A simple Variational Autoencoders

# %% [markdown]
# ### Param

# %%
# network parameters
n_input = 784
batch_size=100
intermediate_dim = 512
latent_dim = 2
epochs = 25

# %% [markdown]
# ### Encoder

# %% [markdown]
# #### Latent Variable

# %% [markdown]
# We first build the encoder part. <br>
# It is first composed of  a `Dense` layer with 512 neurons. <br>
# Two `Dense` layers are then added on **top of the same layer**. These two layers will produce the two variables *z_mean* and  *z_log_var* in the latent space.
#
# Note that we define each layer as a function of an input which is the output of the layer it follows.

# %%
# Input layer
inputs = kl.Input(shape=(784,), name='encoder_input')
# Dense layer from input layer
x = kl.Dense(intermediate_dim, activation='relu')(inputs)
# Two dense layer that takes input from the same layer x
z_mean = kl.Dense(latent_dim, name='z_mean')(x)
z_log_var = kl.Dense(latent_dim, name='z_log_var')(x)
# Out:
# 2022-10-19 11:09:51.750047: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-19 11:09:51.750718: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-10-19 11:09:51.750754: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-19 11:09:51.750794: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-19 11:09:51.750806: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-10-19 11:09:51.750817: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:09:51.750828: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:09:51.750839: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:09:51.750850: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-19 11:09:51.750861: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-19 11:09:51.751700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-19 11:09:51.751890: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-19 11:09:51.752386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-10-19 11:09:51.752407: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-19 11:09:51.752440: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-19 11:09:51.752454: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-10-19 11:09:51.752468: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:09:51.752481: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:09:51.752495: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:09:51.752508: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-19 11:09:51.752521: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-19 11:09:51.753351: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-19 11:09:51.753381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-19 11:09:51.753388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-10-19 11:09:51.753393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-10-19 11:09:51.754241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9987 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:65:00.0, compute capability: 6.1)

# %% [markdown]
# ### The stochastic latent variable
#
# We use the reparametrization trick to define a random variable z that is conditioned on the input image x as follows:
#
# $$ q(z/x) \sim \mathcal{N}(\mu_z(x), \sigma_z(x)) $$
#
# <img src="image/vae_3.svg" width="600px" />
#
#
#
# The reparametrization tricks defines $z$ has follows:
#
# $$ q(z/x) = \mu_z(x) + \sigma_z(x) \cdot \epsilon$$
#
# with:
#
# $$ \epsilon \sim \mathcal{N}(0, 1) $$
#
# This way the dependency to between $z$ and $x$ is deterministic and differentiable. The randomness of $z$ only stems from $\epsilon$ only for a given $x$.
#
# Note that in practice the output of the encoder network parameterizes $log(\sigma^2_z(x))$ instead of $\sigma_z(x)$. <br>
# Taking the exponential of $log(\sigma^2_z(x)$ ensures the positivity of the standard deviation from the raw output of the network.
#
#
# Let's first define a function that takes as an input the output of the `Z_mean`, and `Z_log_var` previous layer and generate a sample from this input.

# %%
# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(batch_size, latent_dim))
    return z_mean + K.exp(z_log_sigma) * epsilon

# %% [markdown]
# Now let's define a keras layer from this function.

# %%
# note that "output_shape" isn't necessary with the TensorFlow backend
# so you could write `Lambda(sampling)([z_mean, z_log_sigma])`
z = kl.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

# %% [markdown]
# So far we have defined all the layers we need to build the encoder part of the vae. <br>
# We now define the model, with the `Model`method. For that we just have to specify the input layer and the output we want (here, it's the latent variable z). The model is then build automatically.

# %%
# instantiate encoder model

encoder = km.Model(inputs, z, name='encoder')
encoder.summary()
#ku.plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          401920      encoder_input[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            1026        dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            1026        dense[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (100, 2)             0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 403,972
# Trainable params: 403,972
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Decoder
#
# The decoder takes as an input the vector z (which is a sample of the latent distribution define by the encoder).
# It is then composed of 2 Dense layers with the following caracteristics :
#
# * 512 neurons, relu activation
# * 784 neurons (input_shape), sigmoid activation
#
# **Exercise** build this simple decoder model using the Model API

# %%
# %load solutions/decoder_vae.py
# build decoder model
latent_inputs = kl.Input(shape=(latent_dim,), name='z_sampling')
x = kl.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = kl.Dense(n_input, activation='sigmoid')(x)

# instantiate decoder model
decoder = km.Model(latent_inputs, outputs, name='decoder')
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(2,), dtype=tf.int32, name=None), inferred_value=[None, 2], name='tf.compat.v1.shape/Shape:0', description="created by layer 'tf.compat.v1.shape'")

# %%
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      [(None, 2)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1536
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               402192
# =================================================================
# Total params: 403,728
# Trainable params: 403,728
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Vae
#
# We now associate the encoder and the decoder to define our Variational Autoencoder.
#
# **Exercise** build this VAE model using the Model API

# %%
vae = km.Sequential(name="vae")

x = kl.Dense(intermediate_dim, activation='relu')(z)
outputs = kl.Dense(n_input, activation='sigmoid')(x)

vae = km.Model(inputs, outputs, name='decoder')
vae.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          401920      encoder_input[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            1026        dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            1026        dense[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (100, 2)             0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (100, 512)           1536        z[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (100, 784)           402192      dense_3[0][0]
# ==================================================================================================
# Total params: 807,700
# Trainable params: 807,700
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %load solutions/vae.py
# instantiate VAE model
outputs = decoder(encoder(inputs))
vae = km.Model(inputs, outputs, name='vae_mlp')
vae.summary()
# Out:
# Model: "vae_mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 784)]             0
# _________________________________________________________________
# encoder (Functional)         (100, 2)                  403972
# _________________________________________________________________
# decoder (Functional)         (None, 784)               403728
# =================================================================
# Total params: 807,700
# Trainable params: 807,700
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We implement now the vae loss function  as described in the course
#
# $$VAE_{loss} = l(x,\hat{x}) + KL(q(z/x),p(z))$$
#
# $l$ can be any loss function betwen the original image $x$ and the reconstructed image $\hat{x}$. Here we use the binary crossentropy.
#
#
# $$ q(z/x) \sim \mathcal{N}(\mu_z(x), \sigma_z(x)), $$
# as described below. $p(z)$ is the latent distribution. The easiest choice  is  to take $p(z)\sim \mathcal{N}(0,1)$.
#
#
# **We first use the following result, that you can check :**
#
# If $P \sim \mathcal{N}_d(\mu_p, \Sigma_p) $ and $Q \sim \mathcal{N}_d(\mu_q, \Sigma_q) $, then
# $$
# KL(Q || P) = \frac{1}{2}\left[\log\frac{|\Sigma_p|}{|\Sigma_q|} - d + \text{tr} \{ \Sigma_p^{-1}\Sigma_q \} + (\mu_p - \mu_q)^T \Sigma_p^{-1}(\mu_p - \mu_q)\right].
# $$
#
# In our case, $p(z) \sim \mathcal{N}_2(0,  I_2) $ and $ q(z/x) \sim \mathcal{N}_2(\mu_z(x),\sigma_z(x)) $. Hence, we have
#
# $
# KL(q(z/x) || p(z)) = \frac{1}{2}\left[-\log|\sigma_z(x)| - d + \text{tr} \{\sigma_z(x) \} +\mu_z(x)^T \mu_z(x)\right].
# $
#
# which can be computed as :
#
# $KL(q(z/x) || p(z)) = \frac{1}{2} \, \sum_{j=1}^2 \left( \sigma_{z,j}(x) + \mu_{z,j}^2(x) - 1 - \log \sigma_{z,j}(x) \right)$

# %%
reconstruction_loss = kloss.binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= 784
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
vae.fit(x_train,
                epochs=40,
                batch_size=batch_size,
                validation_data=(x_test, None))
# Out:
# Epoch 1/40
# 600/600 [==============================] - 3s 4ms/step - loss: 232.9250 - val_loss: 169.2071
# Epoch 2/40
# 600/600 [==============================] - 2s 4ms/step - loss: 167.6044 - val_loss: 164.4081
# Epoch 3/40
# 600/600 [==============================] - 2s 4ms/step - loss: 162.9813 - val_loss: 161.1568
# Epoch 4/40
# 600/600 [==============================] - 2s 4ms/step - loss: 159.7202 - val_loss: 158.7835
# Epoch 5/40
# 600/600 [==============================] - 2s 4ms/step - loss: 157.5967 - val_loss: 157.5000
# Epoch 6/40
# 600/600 [==============================] - 2s 4ms/step - loss: 156.3266 - val_loss: 156.2318
# Epoch 7/40
# 600/600 [==============================] - 2s 4ms/step - loss: 154.7341 - val_loss: 155.6079
# Epoch 8/40
# 600/600 [==============================] - 2s 4ms/step - loss: 153.7856 - val_loss: 154.8620
# Epoch 9/40
# 600/600 [==============================] - 2s 4ms/step - loss: 153.0140 - val_loss: 154.4407
# Epoch 10/40
# 600/600 [==============================] - 2s 4ms/step - loss: 152.5613 - val_loss: 153.8439
# Epoch 11/40
# 600/600 [==============================] - 2s 4ms/step - loss: 152.2812 - val_loss: 153.2834
# Epoch 12/40
# 600/600 [==============================] - 2s 4ms/step - loss: 151.6508 - val_loss: 153.2937
# Epoch 13/40
# 600/600 [==============================] - 2s 4ms/step - loss: 151.1062 - val_loss: 152.6503
# Epoch 14/40
# 600/600 [==============================] - 2s 4ms/step - loss: 150.5210 - val_loss: 152.6452
# Epoch 15/40
# 600/600 [==============================] - 2s 4ms/step - loss: 150.3331 - val_loss: 152.0756
# Epoch 16/40
# 600/600 [==============================] - 2s 4ms/step - loss: 150.0103 - val_loss: 151.9347
# Epoch 17/40
# 600/600 [==============================] - 2s 4ms/step - loss: 149.2933 - val_loss: 151.6861
# Epoch 18/40
# 600/600 [==============================] - 2s 4ms/step - loss: 149.0377 - val_loss: 151.5133
# Epoch 19/40
# 600/600 [==============================] - 2s 4ms/step - loss: 148.8864 - val_loss: 151.3756
# Epoch 20/40
# 600/600 [==============================] - 2s 4ms/step - loss: 148.6079 - val_loss: 151.2245
# Epoch 21/40
# 600/600 [==============================] - 2s 4ms/step - loss: 148.3196 - val_loss: 151.1257
# Epoch 22/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.7483 - val_loss: 150.8065
# Epoch 23/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.8709 - val_loss: 151.0363
# Epoch 24/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.6293 - val_loss: 151.0009
# Epoch 25/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.5616 - val_loss: 150.7888
# Epoch 26/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.0150 - val_loss: 150.5676
# Epoch 27/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.0031 - val_loss: 150.6809
# Epoch 28/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.8618 - val_loss: 150.4438
# Epoch 29/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.4839 - val_loss: 150.3004
# Epoch 30/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.4825 - val_loss: 150.1059
# Epoch 31/40
# 600/600 [==============================] - 2s 3ms/step - loss: 146.1766 - val_loss: 150.2552
# Epoch 32/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.1454 - val_loss: 150.3439
# Epoch 33/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.6212 - val_loss: 150.3103
# Epoch 34/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.9316 - val_loss: 150.0694
# Epoch 35/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.6532 - val_loss: 149.9801
# Epoch 36/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.4768 - val_loss: 149.7464
# Epoch 37/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.4261 - val_loss: 149.8051
# Epoch 38/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.3455 - val_loss: 149.8633
# Epoch 39/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.2268 - val_loss: 149.7895
# Epoch 40/40
# 600/600 [==============================] - 2s 4ms/step - loss: 144.8607 - val_loss: 149.7378

# %% [markdown]
# ### Display images result

# %%
x_test_decoded_vae = vae.predict(x_test, batch_size= batch_size)

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(x_test_decoded_vae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Classification of latent variable

# %%
x_test_encoded = encoder.predict(x_test, batch_size=batch_size)
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1,1,1)
for i in range(10):
    x_test_encoded_i = x_test_encoded[y_test==i]
    plt.scatter(x_test_encoded_i[:, 0], x_test_encoded_i[:, 1], label=i)
ax.grid(False)
plt.legend()

plt.show()

# %% [markdown]
# ## Generation of number

# %% [markdown]
# ### Single Example

# %% [markdown]
# **Exercise** Generate a image number from two random latent variables using the decoder

# %%
imsim= decoder.predict( np.expand_dims((3,2),axis=0))
plt.imshow(imsim[0].reshape(28, 28))

# %%
# %load solutions/generate_single_sample.py
z_latents = np.expand_dims(np.random.normal(0,1,2), axis=0)
x_generate = decoder.predict(z_latents)
plt.imshow(x_generate[0].reshape(28, 28))

# %% [markdown]
# ### View of VAE Manifolds

# %%
n = 15  # figure with 15x15 panels
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = sc.stats.norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = sc.stats.norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()

# %% [markdown]
# ## Anomaly Detection
#
# In this part we'll see how variational autoencoder can be used to anomaly detections.
#
# We will consider that 9 images are outliers.
#
# We will generate four datasets from both train and test dataset, train and test without 9 images and train and test with only 9 images.

# %%
outlier_i = 9
x_train_normal = x_train[y_train!=outlier_i]
n_train = x_train_normal.shape[0]-x_train_normal.shape[0]%100
x_train_normal = x_train_normal[:n_train]
x_test_normal =  x_test[y_test!=outlier_i]
n_test = x_test_normal.shape[0]-x_test_normal.shape[0]%100
x_test_normal = x_test_normal[:n_test]

x_train_outliers = x_train[y_train==outlier_i]
n_train = x_train_outliers.shape[0]-x_train_outliers.shape[0]%100
x_train_outliers = x_train_outliers[:n_train]
x_test_outliers =  x_test[y_test==outlier_i]
n_test = x_test_outliers.shape[0]-x_test_outliers.shape[0]%100
x_test_outliers = x_test_outliers[:n_test]

x_train_normal.shape, x_train_outliers.shape, x_test_normal.shape, x_test_outliers.shape
# Out:
# ((54000, 784), (5900, 784), (8900, 784), (1000, 784))

# %% [markdown]
# **Exervise** Build a VAE as we did above on this notebook and learn weights only on train dataset without 9 images.

# %%
# %load solutions/train_outlier_vae.py
# encoder
inputs = kl.Input(shape=(784,), name='encoder_input')
x = kl.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = kl.Dense(latent_dim, name='z_mean')(x)
z_log_var = kl.Dense(latent_dim, name='z_log_var')(x)
z = kl.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
encoder_ad = km.Model(inputs, z, name='encoder')

# decoder
latent_inputs = kl.Input(shape=(latent_dim,), name='z_sampling')
x = kl.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = kl.Dense(784, activation='sigmoid')(x)
decoder_ad = km.Model(latent_inputs, outputs, name='decoder')

# vae
outputs = decoder_ad(encoder_ad(inputs))
vae_ad = km.Model(inputs, outputs, name='vae_mlp')

reconstruction_loss = kloss.binary_crossentropy(inputs,outputs)
reconstruction_loss *= 784
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae_ad.add_loss(vae_loss)
vae_ad.compile(optimizer='adam')

vae_ad.fit(x_train_normal,epochs=epochs, batch_size=batch_size, validation_data=(x_test_normal, None))
# Out:
# Epoch 1/25
# 540/540 [==============================] - 2s 4ms/step - loss: 242.8072 - val_loss: 180.2715
# Epoch 2/25
# 540/540 [==============================] - 2s 4ms/step - loss: 177.3178 - val_loss: 169.0734
# Epoch 3/25
# 540/540 [==============================] - 2s 4ms/step - loss: 169.1063 - val_loss: 165.3849
# Epoch 4/25
# 540/540 [==============================] - 2s 4ms/step - loss: 164.7766 - val_loss: 162.6299
# Epoch 5/25
# 540/540 [==============================] - 2s 4ms/step - loss: 162.0270 - val_loss: 160.4491
# Epoch 6/25
# 540/540 [==============================] - 2s 4ms/step - loss: 159.9981 - val_loss: 159.0128
# Epoch 7/25
# 540/540 [==============================] - 2s 4ms/step - loss: 158.5539 - val_loss: 157.5565
# Epoch 8/25
# 540/540 [==============================] - 2s 4ms/step - loss: 157.3146 - val_loss: 156.4869
# Epoch 9/25
# 540/540 [==============================] - 2s 4ms/step - loss: 155.6103 - val_loss: 155.9191
# Epoch 10/25
# 540/540 [==============================] - 2s 4ms/step - loss: 155.0745 - val_loss: 154.8640
# Epoch 11/25
# 540/540 [==============================] - 2s 4ms/step - loss: 154.2769 - val_loss: 153.9868
# Epoch 12/25
# 540/540 [==============================] - 2s 4ms/step - loss: 153.3174 - val_loss: 154.0129
# Epoch 13/25
# 540/540 [==============================] - 2s 4ms/step - loss: 152.4683 - val_loss: 153.2487
# Epoch 14/25
# 540/540 [==============================] - 2s 4ms/step - loss: 151.7026 - val_loss: 152.6137
# Epoch 15/25
# 540/540 [==============================] - 2s 4ms/step - loss: 150.6414 - val_loss: 152.2312
# Epoch 16/25
# 540/540 [==============================] - 2s 4ms/step - loss: 150.7089 - val_loss: 151.9085
# Epoch 17/25
# 540/540 [==============================] - 2s 4ms/step - loss: 149.7273 - val_loss: 151.8092
# Epoch 18/25
# 540/540 [==============================] - 2s 4ms/step - loss: 149.4151 - val_loss: 151.7984
# Epoch 19/25
# 540/540 [==============================] - 2s 4ms/step - loss: 149.2801 - val_loss: 151.3772
# Epoch 20/25
# 540/540 [==============================] - 2s 4ms/step - loss: 149.1607 - val_loss: 151.1852
# Epoch 21/25
# 540/540 [==============================] - 2s 4ms/step - loss: 148.7515 - val_loss: 150.8784
# Epoch 22/25
# 540/540 [==============================] - 2s 4ms/step - loss: 148.2156 - val_loss: 150.6639
# Epoch 23/25
# 540/540 [==============================] - 2s 4ms/step - loss: 147.9743 - val_loss: 150.7605
# Epoch 24/25
# 540/540 [==============================] - 2s 4ms/step - loss: 147.5488 - val_loss: 150.4892
# Epoch 25/25
# 540/540 [==============================] - 2s 4ms/step - loss: 147.5088 - val_loss: 150.5844

# %%
outputs = decoder(encoder(inputs))
vae2 = km.Model(inputs, outputs, name='vae_mlp')
vae2.summary()

reconstruction_loss = kloss.binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= 784
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae2_loss = K.mean(reconstruction_loss + kl_loss)
vae2.add_loss(vae2_loss)
vae2.compile(optimizer='adam')


vae2.fit(x_train_normal,
                epochs=40,
                batch_size=batch_size,
                validation_data=(x_test_normal, None))
# Out:
# Model: "vae_mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 784)]             0
# _________________________________________________________________
# encoder (Functional)         (100, 2)                  403972
# _________________________________________________________________
# decoder (Functional)         (None, 784)               403728
# =================================================================
# Total params: 807,700
# Trainable params: 807,700
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 540/540 [==============================] - 2s 4ms/step - loss: 162.2979 - val_loss: 152.7272
# Epoch 2/40
# 540/540 [==============================] - 2s 4ms/step - loss: 147.5677 - val_loss: 151.9782
# Epoch 3/40
# 540/540 [==============================] - 2s 4ms/step - loss: 147.3569 - val_loss: 151.8132
# Epoch 4/40
# 540/540 [==============================] - 2s 4ms/step - loss: 146.4855 - val_loss: 151.9506
# Epoch 5/40
# 540/540 [==============================] - 2s 4ms/step - loss: 146.1258 - val_loss: 151.8726
# Epoch 6/40
# 540/540 [==============================] - 2s 4ms/step - loss: 146.1067 - val_loss: 151.1238
# Epoch 7/40
# 540/540 [==============================] - 2s 4ms/step - loss: 145.5408 - val_loss: 151.4841
# Epoch 8/40
# 540/540 [==============================] - 2s 4ms/step - loss: 145.6360 - val_loss: 151.0666
# Epoch 9/40
# 540/540 [==============================] - 2s 4ms/step - loss: 145.2708 - val_loss: 151.3647
# Epoch 10/40
# 540/540 [==============================] - 2s 4ms/step - loss: 145.2927 - val_loss: 151.1898
# Epoch 11/40
# 540/540 [==============================] - 2s 4ms/step - loss: 145.0625 - val_loss: 151.4412
# Epoch 12/40
# 540/540 [==============================] - 2s 3ms/step - loss: 145.1139 - val_loss: 151.0901
# Epoch 13/40
# 540/540 [==============================] - 2s 4ms/step - loss: 144.9537 - val_loss: 151.4715
# Epoch 14/40
# 540/540 [==============================] - 2s 3ms/step - loss: 144.7440 - val_loss: 150.9775
# Epoch 15/40
# 540/540 [==============================] - 2s 3ms/step - loss: 144.8589 - val_loss: 151.1864
# Epoch 16/40
# 540/540 [==============================] - 2s 4ms/step - loss: 144.2239 - val_loss: 151.0211
# Epoch 17/40
# 540/540 [==============================] - 2s 4ms/step - loss: 144.3153 - val_loss: 150.8907
# Epoch 18/40
# 540/540 [==============================] - 2s 4ms/step - loss: 144.2687 - val_loss: 150.9385
# Epoch 19/40
# 540/540 [==============================] - 2s 4ms/step - loss: 144.5748 - val_loss: 151.0656
# Epoch 20/40
# 540/540 [==============================] - 2s 4ms/step - loss: 144.5107 - val_loss: 150.9588
# Epoch 21/40
# 540/540 [==============================] - 2s 4ms/step - loss: 143.9928 - val_loss: 151.1136
# Epoch 22/40
# 540/540 [==============================] - 2s 4ms/step - loss: 144.3512 - val_loss: 150.8185
# Epoch 23/40
# 540/540 [==============================] - 2s 3ms/step - loss: 143.9210 - val_loss: 150.9647
# Epoch 24/40
# 540/540 [==============================] - 2s 4ms/step - loss: 143.6033 - val_loss: 151.1597
# Epoch 25/40
# 540/540 [==============================] - 2s 4ms/step - loss: 143.7236 - val_loss: 150.7437
# Epoch 26/40
# 540/540 [==============================] - 2s 3ms/step - loss: 143.3643 - val_loss: 150.8414
# Epoch 27/40
# 540/540 [==============================] - 2s 4ms/step - loss: 143.5645 - val_loss: 150.9058
# Epoch 28/40
# 540/540 [==============================] - 2s 4ms/step - loss: 143.6786 - val_loss: 151.1177
# Epoch 29/40
# 540/540 [==============================] - 2s 4ms/step - loss: 143.1130 - val_loss: 150.6950
# Epoch 30/40
# 540/540 [==============================] - 2s 3ms/step - loss: 143.4014 - val_loss: 150.9917
# Epoch 31/40
# 540/540 [==============================] - 2s 3ms/step - loss: 143.3264 - val_loss: 150.6728
# Epoch 32/40
# 540/540 [==============================] - 2s 4ms/step - loss: 142.9233 - val_loss: 150.6973
# Epoch 33/40
# 540/540 [==============================] - 2s 4ms/step - loss: 142.7140 - val_loss: 150.8742
# Epoch 34/40
# 540/540 [==============================] - 2s 4ms/step - loss: 143.2751 - val_loss: 150.9777
# Epoch 35/40
# 540/540 [==============================] - 2s 4ms/step - loss: 142.8163 - val_loss: 151.0031
# Epoch 36/40
# 540/540 [==============================] - 2s 4ms/step - loss: 142.8019 - val_loss: 150.9579
# Epoch 37/40
# 540/540 [==============================] - 2s 3ms/step - loss: 142.6121 - val_loss: 150.7762
# Epoch 38/40
# 540/540 [==============================] - 2s 4ms/step - loss: 142.4091 - val_loss: 150.6926
# Epoch 39/40
# 540/540 [==============================] - 2s 4ms/step - loss: 142.4859 - val_loss: 150.6721
# Epoch 40/40
# 540/540 [==============================] - 2s 4ms/step - loss: 142.8648 - val_loss: 150.9947

# %% [markdown]
# ### Display decoded image
#
# Let's now try to use our VAE on test dataset with both known numbers (0 to 8) and with outliers (9)

# %% [markdown]
# #### Normal Dataset

# %%
x_test_decoded_vae = vae_ad.predict(x_test_normal, batch_size=batch_size)

# %%
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test_normal[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(x_test_decoded_vae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# #### Outlier Dataset

# %%
x_test_decoded_vae = vae_ad.predict(x_test_outliers, batch_size=batch_size)
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_outliers[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(x_test_decoded_vae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# **Question** : What can you say about the decoded images in both cases? Is it normal?

# %% [markdown]
# ### Error Distribution
#
# To evaluate how the detection of 9 images will work, let us check the distribution of the different l2 errors between the original image and their reconstructed image for three types if images:
#
# * Images of know number (0 to 8)
# * Images of outlier (9)
# * Completly randomly generated images
#
# **Exercise** Generate these distributions

# %%
# %load solutions/error_distribution.py
x_test_normal_decoded = vae_ad.predict(x_test_normal, batch_size=batch_size)
error_normal = np.linalg.norm(x_test_normal-x_test_normal_decoded, axis=1)

x_test_outliers_decoded = vae_ad.predict(x_test_outliers, batch_size =batch_size)
error_outliers = np.linalg.norm(x_test_outliers-x_test_outliers_decoded, axis=1)

x_random = np.random.uniform(size=(1000, 784),low=0.0, high=1.0)
x_random_decoded =  vae_ad.predict(x_random, batch_size=batch_size)
error_random = np.linalg.norm(x_random-x_random_decoded, axis=1)

# %%
fig=plt.figure(figsize=(9,5))
ax = fig.add_subplot(1,1,1)
sb.distplot(error_normal, ax=ax, label="Normal")
sb.distplot(error_outliers, ax=ax, label="Outliers")
sb.distplot(error_random , ax=ax, label="Random")

plt.legend()
# Out:
# /usr/local/insa/anaconda/envs/IA-GPU/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/insa/anaconda/envs/IA-GPU/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/insa/anaconda/envs/IA-GPU/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Question** What can you say about the error reconstruction of the different cases? What does it say about the performance of VAE to detect anomalies ?

# %% [markdown]
# ## Convolutional Network
#
# **Exercise** You've seen how to build VAE and how to use it to generate new images and to detect anomalies. The VAE used so far only use Dense layer.
#
# Use CNN layers to build a convolutional VAE and test the different applications (generate images and detect anomalies)
